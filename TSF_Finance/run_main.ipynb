# %%
seq_len=104
pred_len=36
model_name="PatchTST"

root_path_name="/Users/Ella/Desktop/PatchTST-main/PatchTST_supervised/dataset/"
data_path_name = "national_illness.csv"
#root_path_name=./dataset/
#data_path_name=national_illness.csv
model_id_name="national_illness"
data_name="custom"
#"^IXIC.csv"

random_seed=2021

# %%
seq_len=104
pred_len=36
patch_len =24

# %% [markdown]
# ## PatchTST - CI

# %%
#train
# !python -u run_longExp.py \
      --random_seed 2021 \
      --is_training 1 \
      --root_path '/Users/Ella/Desktop/Investment/finance_data/' \
      --data_path ixic_stm_0705.csv \
      --model_id ixic_stm_0705'_' \
      --model "PatchTST" \
      --data "custom" \
      --features M \
      --seq_len 96 \
      --pred_len 15 \
      --enc_in 4 \
      --e_layers 3 \
      --n_heads 4 \
      --d_model 16 \
      --d_ff 128 \
      --dropout 0.3\
      --fc_dropout 0.3\
      --head_dropout 0\
      --patch_len 24\
      --stride 2\
      --des 'Exp' \
      --train_epochs 100\
      --lradj 'constant'\
      --itr 1 --batch_size 16 --learning_rate 0.00001
# Out:
# /Users/Ella/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)
# Args in experiment:
# ...

# %%
#Test and Predict

# %%
# !python -u run_longExp.py \
      --random_seed 2021 \
      --is_training 0 \
      --root_path '/Users/Ella/Desktop/Investment/finance_data/' \
      --data_path ixic_stm_0705.csv \
      --model_id ixic_stm_0705'_' \
      --model "PatchTST" \
      --data "custom" \
      --features M \
      --seq_len 96 \
      --pred_len 15 \
      --enc_in 4 \
      --e_layers 3 \
      --n_heads 4 \
      --d_model 16 \
      --d_ff 128 \
      --dropout 0.3\
      --fc_dropout 0.3\
      --head_dropout 0\
      --patch_len 24\
      --stride 2\
      --des 'Exp' \
      --train_epochs 100\
      --lradj 'constant'\
      --do_predict \
      --itr 1 --batch_size 16 --learning_rate 0.00001
# Out:
# /Users/Ella/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)
# Args in experiment:
# ...

# %% [markdown]
# ## Linear model
